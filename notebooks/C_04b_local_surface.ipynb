# %% [markdown]
# # 04b · Fondo local (superficie)
#
# **Spec:** —  |  **Bloque:** C · Extracción  |  **Run por defecto:** `ROXs12b_realigned`
#
# Sustrae una superficie local al fondo alrededor del compañero.
#
# | | |
# |---|---|
# | **Entrada** | Cubo alineado (native_stage02) |
# | **Salida (QC/productos)** | `stages/stage04b_qc.json` |
# | **Consume aguas abajo** | C2/C3 (control local) |

# %% [markdown]
# ## Cómo ejecutar de forma independiente
#
# ```bash
# conda activate MUSE               # kernel/env con astropy + musepipe
# export RUN=ROXs12b_realigned   # o ROXs12b_B_adp para comparar
# cd MUSE-accretion-pipeline                    # raíz del repo
# python -c "from musepipe.stages.stage04b_local_surface import run_stage04b; run_stage04b('$RUN')"
# ```
#
# Ligero–moderado.
#
# La celda de abajo hace lo mismo desde el notebook (guardada por `RUN`).

# %%
import os, sys
sys.path.insert(0, os.path.dirname(os.path.abspath('_nbcommon.py')))
import _nbcommon as nb
RUN_ID = nb.resolve_run_id(None)
print('run =', RUN_ID)
print('dir =', nb.run_dir(RUN_ID))

# %% [markdown]
# ## Ejecutar o auditar

# %%
RUN = False   # -> True para RE-EJECUTAR esta etapa (regenera su QC)

if RUN:
    cmd = 'python -c "from musepipe.stages.stage04b_local_surface import run_stage04b; run_stage04b(\'$RUN\')"'.replace('$RUN', RUN_ID)
    print('ejecutando:', cmd)
    import subprocess
    subprocess.run(cmd, shell=True, cwd=str(nb.project_root()), check=True)
else:
    print('Modo auditoría (RUN=False): se carga el QC existente abajo.')

# %% [markdown]
# ## QC / resultados

# %%
qc = nb.load_qc('stages/stage04b_qc.json', RUN_ID)
nb.show(qc, keys=['surface', 'residual', 'pedestal', 'mode'], title='04b')

# %% [markdown]
# ## Decisiones y notas
# - Uso operativo de la cadena local para ROXs12b documentado en la guía. · [`docs/roxs12b_clean_spectrum_pipeline.md`](../docs/roxs12b_clean_spectrum_pipeline.md)

# %% [markdown]
# ## Checks

# %%
nb.show(qc, keys=['residual','mode'])
